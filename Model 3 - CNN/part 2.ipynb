# %% [markdown]
# # MODEL 3: CNN
# Omar Ebrahim & Kareem Eltouny

# %% [markdown]
# STEP 1: Importing the libraries.

# %%
import time
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import RandomizedSearchCV

from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from keras import Input

# %% [markdown]
# STEP 2: Importing the dataset & splitting them to training and testing.

# %%
fashionTrain = pd.read_csv("fashion-mnist_train.csv")
fashionTest = pd.read_csv("fashion-mnist_test.csv")

# The splitting was done without a library instead of using the train test split function.
# This is due to us reading from 2 separate CSV files.
X_train = fashionTrain.iloc[:, 1:]
y_train = fashionTrain.iloc[:, 0]
X_test = fashionTest.iloc[:, 1:]
y_test = fashionTest.iloc[:, 0]

X_train = np.array(X_train)
X_test = np.array(X_test)
X_train = X_train.reshape((-1, 28, 28, 1))
X_test = X_test.reshape((-1, 28, 28, 1))

X_train.shape
# Out:
# (60000, 28, 28, 1)

# %% [markdown]
# STEP 3: Pre-Processing Part 1: Normalization

# %%
# Pixels are in range 0 to 255.
# The range that a single 8-bit byte can offer.
# We normalized X and y as ‘float32’, which means that it is of single precision and cuts the memory in half.
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
# They need to be scaled down to [0,1] in order for Optimization Algorithms to work much faster. 
X_train /= 255.0
X_test /=255.0

# %% [markdown]
# STEP 4: Training the CNN Model.

# %%
# Creating the sequential model.
model = Sequential()
# Input layer with a shape of (28, 28, 1) which is addressing grayscale image.
model.add(Input(shape=(28, 28, 1)))
# Convolutional layer with 32 filters, a kernel size of (3, 3).
model.add(Conv2D(filters=32,
                 kernel_size=(3, 3),
                 activation='relu',
                 padding='valid',
                 strides=(1, 1)))
# MaxPooling layer with a pool size of (2, 2) to down-sample any spatial dimensions.
model.add(MaxPooling2D(pool_size=(2, 2)))
# Convolutional layer with 64 filters, a kernel size of (3, 3),
# ReLU activation, valid padding, and stride of (1, 1)
model.add(Conv2D(filters=64,
                 kernel_size=(3, 3),
                 activation='relu',
                 padding='valid',
                 strides=(1, 1)))
model.add(MaxPooling2D())
model.add(Flatten())
# Dropout rate of 0.5 to prevent overfitting.
model.add(Dropout(0.5))
# Softmax activation used for multi-class classification.
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dropout (Dropout)           (None, 1600)              0
#
#  dense (Dense)               (None, 10)                16010
#
# =================================================================
# Total params: 34826 (136.04 KB)
# Trainable params: 34826 (136.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# adam optimizer used for robustness to noisy graidents.
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# These generated a good accuracy score. Other hyperparameters were tested on a separate file.
hist = model.fit(X_train, y_train, epochs=150, batch_size=64, validation_split=0.05)
# Out:
# Epoch 1/150
# 891/891 [==============================] - 40s 43ms/step - loss: 0.6144 - accuracy: 0.7773 - val_loss: 0.4144 - val_accuracy: 0.8583
# Epoch 2/150
# 891/891 [==============================] - 36s 40ms/step - loss: 0.4223 - accuracy: 0.8501 - val_loss: 0.3645 - val_accuracy: 0.8757
# Epoch 3/150
# 891/891 [==============================] - 34s 38ms/step - loss: 0.3787 - accuracy: 0.8641 - val_loss: 0.3404 - val_accuracy: 0.8740
# Epoch 4/150
# 891/891 [==============================] - 33s 38ms/step - loss: 0.3523 - accuracy: 0.8725 - val_loss: 0.3209 - val_accuracy: 0.8800
# Epoch 5/150
# 891/891 [==============================] - 34s 39ms/step - loss: 0.3280 - accuracy: 0.8813 - val_loss: 0.2949 - val_accuracy: 0.8957
# Epoch 6/150
# 891/891 [==============================] - 36s 40ms/step - loss: 0.3151 - accuracy: 0.8874 - val_loss: 0.2849 - val_accuracy: 0.8987
# Epoch 7/150
# 891/891 [==============================] - 34s 38ms/step - loss: 0.3029 - accuracy: 0.8906 - val_loss: 0.2800 - val_accuracy: 0.9013
# Epoch 8/150
# 891/891 [==============================] - 39s 44ms/step - loss: 0.2929 - accuracy: 0.8942 - val_loss: 0.2744 - val_accuracy: 0.9010
# Epoch 9/150
# 891/891 [==============================] - 35s 40ms/step - loss: 0.2879 - accuracy: 0.8959 - val_loss: 0.2786 - val_accuracy: 0.8977
# Epoch 10/150
# 891/891 [==============================] - 34s 38ms/step - loss: 0.2791 - accuracy: 0.8975 - val_loss: 0.2728 - val_accuracy: 0.9030
# Epoch 11/150
# 891/891 [==============================] - 34s 39ms/step - loss: 0.2743 - accuracy: 0.9010 - val_loss: 0.2600 - val_accuracy: 0.9043
# Epoch 12/150
# 891/891 [==============================] - 34s 38ms/step - loss: 0.2719 - accuracy: 0.9010 - val_loss: 0.2617 - val_accuracy: 0.9073
# Epoch 13/150
# 891/891 [==============================] - 34s 39ms/step - loss: 0.2649 - accuracy: 0.9040 - val_loss: 0.2538 - val_accuracy: 0.9087
# Epoch 14/150
# 891/891 [==============================] - 35s 39ms/step - loss: 0.2599 - accuracy: 0.9045 - val_loss: 0.2644 - val_accuracy: 0.9050
# Epoch 15/150
# 891/891 [==============================] - 36s 41ms/step - loss: 0.2575 - accuracy: 0.9061 - val_loss: 0.2548 - val_accuracy: 0.9073
# Epoch 16/150
# 891/891 [==============================] - 32s 36ms/step - loss: 0.2510 - accuracy: 0.9082 - val_loss: 0.2492 - val_accuracy: 0.9143
# Epoch 17/150
# 891/891 [==============================] - 30s 34ms/step - loss: 0.2480 - accuracy: 0.9079 - val_loss: 0.2481 - val_accuracy: 0.9133
# Epoch 18/150
# 891/891 [==============================] - 33s 37ms/step - loss: 0.2449 - accuracy: 0.9095 - val_loss: 0.2429 - val_accuracy: 0.9143
# Epoch 19/150
# 891/891 [==============================] - 33s 38ms/step - loss: 0.2418 - accuracy: 0.9109 - val_loss: 0.2445 - val_accuracy: 0.9123
# Epoch 20/150
# 891/891 [==============================] - 35s 39ms/step - loss: 0.2383 - accuracy: 0.9120 - val_loss: 0.2468 - val_accuracy: 0.9100
# Epoch 21/150
# 891/891 [==============================] - 36s 40ms/step - loss: 0.2376 - accuracy: 0.9126 - val_loss: 0.2491 - val_accuracy: 0.9100
# Epoch 22/150
# 891/891 [==============================] - 39s 44ms/step - loss: 0.2330 - accuracy: 0.9153 - val_loss: 0.2385 - val_accuracy: 0.9150
# Epoch 23/150
# 891/891 [==============================] - 34s 38ms/step - loss: 0.2295 - accuracy: 0.9156 - val_loss: 0.2329 - val_accuracy: 0.9193
# Epoch 24/150
# 891/891 [==============================] - 36s 40ms/step - loss: 0.2311 - accuracy: 0.9142 - val_loss: 0.2370 - val_accuracy: 0.9167
# Epoch 25/150
# 891/891 [==============================] - 35s 39ms/step - loss: 0.2272 - accuracy: 0.9159 - val_loss: 0.2356 - val_accuracy: 0.9163
# Epoch 26/150
# 891/891 [==============================] - 51s 57ms/step - loss: 0.2258 - accuracy: 0.9171 - val_loss: 0.2400 - val_accuracy: 0.9150
# Epoch 27/150
# 891/891 [==============================] - 47s 53ms/step - loss: 0.2235 - accuracy: 0.9182 - val_loss: 0.2431 - val_accuracy: 0.9127
# Epoch 28/150
# 891/891 [==============================] - 48s 54ms/step - loss: 0.2208 - accuracy: 0.9195 - val_loss: 0.2335 - val_accuracy: 0.9177
# Epoch 29/150
# 891/891 [==============================] - 38s 43ms/step - loss: 0.2197 - accuracy: 0.9193 - val_loss: 0.2538 - val_accuracy: 0.9077
# Epoch 30/150
# 891/891 [==============================] - 37s 41ms/step - loss: 0.2144 - accuracy: 0.9214 - val_loss: 0.2324 - val_accuracy: 0.9150
# Epoch 31/150
# 891/891 [==============================] - 37s 41ms/step - loss: 0.2165 - accuracy: 0.9211 - val_loss: 0.2353 - val_accuracy: 0.9137
# Epoch 32/150
# 891/891 [==============================] - 50s 56ms/step - loss: 0.2161 - accuracy: 0.9195 - val_loss: 0.2367 - val_accuracy: 0.9203
# Epoch 33/150
# 891/891 [==============================] - 43s 49ms/step - loss: 0.2134 - accuracy: 0.9215 - val_loss: 0.2398 - val_accuracy: 0.9167
# Epoch 34/150
# 891/891 [==============================] - 41s 46ms/step - loss: 0.2123 - accuracy: 0.9209 - val_loss: 0.2421 - val_accuracy: 0.9137
# Epoch 35/150
# 891/891 [==============================] - 42s 47ms/step - loss: 0.2096 - accuracy: 0.9232 - val_loss: 0.2258 - val_accuracy: 0.9147
# Epoch 36/150
# 891/891 [==============================] - 39s 44ms/step - loss: 0.2089 - accuracy: 0.9218 - val_loss: 0.2328 - val_accuracy: 0.9157
# Epoch 37/150
# 891/891 [==============================] - 46s 52ms/step - loss: 0.2056 - accuracy: 0.9247 - val_loss: 0.2355 - val_accuracy: 0.9153
# Epoch 38/150
# 891/891 [==============================] - 41s 46ms/step - loss: 0.2072 - accuracy: 0.9234 - val_loss: 0.2510 - val_accuracy: 0.9123
# Epoch 39/150
# 891/891 [==============================] - 35s 40ms/step - loss: 0.2064 - accuracy: 0.9230 - val_loss: 0.2376 - val_accuracy: 0.9157
# Epoch 40/150
# 891/891 [==============================] - 33s 37ms/step - loss: 0.2017 - accuracy: 0.9249 - val_loss: 0.2347 - val_accuracy: 0.9170
# Epoch 41/150
# 891/891 [==============================] - 43s 48ms/step - loss: 0.2038 - accuracy: 0.9239 - val_loss: 0.2458 - val_accuracy: 0.9113
# Epoch 42/150
# 891/891 [==============================] - 41s 46ms/step - loss: 0.1971 - accuracy: 0.9273 - val_loss: 0.2279 - val_accuracy: 0.9167
# Epoch 43/150
# 891/891 [==============================] - 40s 45ms/step - loss: 0.1986 - accuracy: 0.9263 - val_loss: 0.2300 - val_accuracy: 0.9183
# Epoch 44/150
# 891/891 [==============================] - 40s 45ms/step - loss: 0.2005 - accuracy: 0.9261 - val_loss: 0.2378 - val_accuracy: 0.9133
# Epoch 45/150
# 891/891 [==============================] - 38s 43ms/step - loss: 0.2015 - accuracy: 0.9254 - val_loss: 0.2301 - val_accuracy: 0.9177
# Epoch 46/150
# 891/891 [==============================] - 37s 41ms/step - loss: 0.1975 - accuracy: 0.9269 - val_loss: 0.2360 - val_accuracy: 0.9133
# Epoch 47/150
# 891/891 [==============================] - 38s 42ms/step - loss: 0.1965 - accuracy: 0.9277 - val_loss: 0.2441 - val_accuracy: 0.9080
# Epoch 48/150
# 891/891 [==============================] - 38s 43ms/step - loss: 0.1937 - accuracy: 0.9286 - val_loss: 0.2321 - val_accuracy: 0.9153
# Epoch 49/150
# 891/891 [==============================] - 37s 41ms/step - loss: 0.1939 - accuracy: 0.9266 - val_loss: 0.2332 - val_accuracy: 0.9163
# Epoch 50/150
# 891/891 [==============================] - 36s 41ms/step - loss: 0.1928 - accuracy: 0.9286 - val_loss: 0.2258 - val_accuracy: 0.9193
# Epoch 51/150
# 891/891 [==============================] - 36s 40ms/step - loss: 0.1902 - accuracy: 0.9288 - val_loss: 0.2312 - val_accuracy: 0.9183
# Epoch 52/150
# 891/891 [==============================] - 36s 41ms/step - loss: 0.1898 - accuracy: 0.9293 - val_loss: 0.2276 - val_accuracy: 0.9170
# Epoch 53/150
# 891/891 [==============================] - 39s 43ms/step - loss: 0.1892 - accuracy: 0.9303 - val_loss: 0.2302 - val_accuracy: 0.9150
# Epoch 54/150
# 891/891 [==============================] - 35s 40ms/step - loss: 0.1914 - accuracy: 0.9286 - val_loss: 0.2313 - val_accuracy: 0.9190
# Epoch 55/150
# 891/891 [==============================] - 36s 41ms/step - loss: 0.1853 - accuracy: 0.9306 - val_loss: 0.2385 - val_accuracy: 0.9183
# Epoch 56/150
# 891/891 [==============================] - 35s 39ms/step - loss: 0.1845 - accuracy: 0.9322 - val_loss: 0.2340 - val_accuracy: 0.9183
# Epoch 57/150
# 891/891 [==============================] - 34s 39ms/step - loss: 0.1857 - accuracy: 0.9311 - val_loss: 0.2425 - val_accuracy: 0.9167
# Epoch 58/150
# 891/891 [==============================] - 34s 39ms/step - loss: 0.1853 - accuracy: 0.9307 - val_loss: 0.2391 - val_accuracy: 0.9180
# Epoch 59/150
# 891/891 [==============================] - 35s 39ms/step - loss: 0.1853 - accuracy: 0.9313 - val_loss: 0.2383 - val_accuracy: 0.9177
# Epoch 60/150
# 891/891 [==============================] - 42s 47ms/step - loss: 0.1813 - accuracy: 0.9342 - val_loss: 0.2519 - val_accuracy: 0.9143
# Epoch 61/150
# 891/891 [==============================] - 44s 49ms/step - loss: 0.1854 - accuracy: 0.9318 - val_loss: 0.2447 - val_accuracy: 0.9153
# Epoch 62/150
# 891/891 [==============================] - 47s 52ms/step - loss: 0.1836 - accuracy: 0.9326 - val_loss: 0.2425 - val_accuracy: 0.9157
# Epoch 63/150
# 891/891 [==============================] - 40s 45ms/step - loss: 0.1832 - accuracy: 0.9328 - val_loss: 0.2480 - val_accuracy: 0.9083
# Epoch 64/150
# 891/891 [==============================] - 34s 38ms/step - loss: 0.1807 - accuracy: 0.9319 - val_loss: 0.2416 - val_accuracy: 0.9133
# Epoch 65/150
# 891/891 [==============================] - 36s 40ms/step - loss: 0.1803 - accuracy: 0.9340 - val_loss: 0.2512 - val_accuracy: 0.9133
# Epoch 66/150
# 891/891 [==============================] - 35s 40ms/step - loss: 0.1787 - accuracy: 0.9337 - val_loss: 0.2449 - val_accuracy: 0.9123
# Epoch 67/150
# 891/891 [==============================] - 35s 39ms/step - loss: 0.1793 - accuracy: 0.9323 - val_loss: 0.2422 - val_accuracy: 0.9183
# Epoch 68/150
# 891/891 [==============================] - 36s 40ms/step - loss: 0.1792 - accuracy: 0.9332 - val_loss: 0.2435 - val_accuracy: 0.9147
# Epoch 69/150
# 891/891 [==============================] - 34s 38ms/step - loss: 0.1792 - accuracy: 0.9330 - val_loss: 0.2631 - val_accuracy: 0.9080
# Epoch 70/150
# 891/891 [==============================] - 38s 42ms/step - loss: 0.1786 - accuracy: 0.9332 - val_loss: 0.2406 - val_accuracy: 0.9170
# Epoch 71/150
# 891/891 [==============================] - 36s 40ms/step - loss: 0.1763 - accuracy: 0.9344 - val_loss: 0.2459 - val_accuracy: 0.9157
# Epoch 72/150
# 891/891 [==============================] - 54s 60ms/step - loss: 0.1754 - accuracy: 0.9345 - val_loss: 0.2506 - val_accuracy: 0.9123
# Epoch 73/150
# 891/891 [==============================] - 70s 79ms/step - loss: 0.1774 - accuracy: 0.9342 - val_loss: 0.2438 - val_accuracy: 0.9157
# Epoch 74/150
# 891/891 [==============================] - 88s 99ms/step - loss: 0.1734 - accuracy: 0.9366 - val_loss: 0.2464 - val_accuracy: 0.9147
# Epoch 75/150
# 891/891 [==============================] - 90s 101ms/step - loss: 0.1734 - accuracy: 0.9353 - val_loss: 0.2514 - val_accuracy: 0.9140
# Epoch 76/150
# 891/891 [==============================] - 88s 99ms/step - loss: 0.1739 - accuracy: 0.9364 - val_loss: 0.2469 - val_accuracy: 0.9180
# Epoch 77/150
# 891/891 [==============================] - 64s 72ms/step - loss: 0.1724 - accuracy: 0.9353 - val_loss: 0.2408 - val_accuracy: 0.9190
# Epoch 78/150
# 891/891 [==============================] - 36s 40ms/step - loss: 0.1725 - accuracy: 0.9362 - val_loss: 0.2502 - val_accuracy: 0.9140
# Epoch 79/150
# 891/891 [==============================] - 29s 32ms/step - loss: 0.1748 - accuracy: 0.9344 - val_loss: 0.2405 - val_accuracy: 0.9190
# Epoch 80/150
# 891/891 [==============================] - 28s 32ms/step - loss: 0.1721 - accuracy: 0.9357 - val_loss: 0.2495 - val_accuracy: 0.9147
# Epoch 81/150
# 891/891 [==============================] - 29s 32ms/step - loss: 0.1678 - accuracy: 0.9376 - val_loss: 0.2430 - val_accuracy: 0.9133
# Epoch 82/150
# 891/891 [==============================] - 28s 32ms/step - loss: 0.1718 - accuracy: 0.9361 - val_loss: 0.2441 - val_accuracy: 0.9160
# Epoch 83/150
# 891/891 [==============================] - 28s 32ms/step - loss: 0.1713 - accuracy: 0.9369 - val_loss: 0.2465 - val_accuracy: 0.9173
# Epoch 84/150
# 891/891 [==============================] - 28s 32ms/step - loss: 0.1692 - accuracy: 0.9370 - val_loss: 0.2494 - val_accuracy: 0.9083
# Epoch 85/150
# 891/891 [==============================] - 28s 32ms/step - loss: 0.1688 - accuracy: 0.9370 - val_loss: 0.2550 - val_accuracy: 0.9190
# Epoch 86/150
# 891/891 [==============================] - 29s 33ms/step - loss: 0.1665 - accuracy: 0.9378 - val_loss: 0.2414 - val_accuracy: 0.9160
# Epoch 87/150
# 891/891 [==============================] - 28s 32ms/step - loss: 0.1682 - accuracy: 0.9374 - val_loss: 0.2486 - val_accuracy: 0.9180
# Epoch 88/150
# 891/891 [==============================] - 28s 32ms/step - loss: 0.1640 - accuracy: 0.9392 - val_loss: 0.2454 - val_accuracy: 0.9127
# Epoch 89/150
# 891/891 [==============================] - 28s 31ms/step - loss: 0.1682 - accuracy: 0.9368 - val_loss: 0.2469 - val_accuracy: 0.9173
# Epoch 90/150
# 891/891 [==============================] - 29s 32ms/step - loss: 0.1691 - accuracy: 0.9376 - val_loss: 0.2395 - val_accuracy: 0.9183
# Epoch 91/150
# 891/891 [==============================] - 28s 31ms/step - loss: 0.1628 - accuracy: 0.9385 - val_loss: 0.2519 - val_accuracy: 0.9160
# Epoch 92/150
# 891/891 [==============================] - 28s 31ms/step - loss: 0.1647 - accuracy: 0.9393 - val_loss: 0.2435 - val_accuracy: 0.9147
# Epoch 93/150
# 891/891 [==============================] - 28s 31ms/step - loss: 0.1646 - accuracy: 0.9376 - val_loss: 0.2422 - val_accuracy: 0.9127
# Epoch 94/150
# 891/891 [==============================] - 28s 32ms/step - loss: 0.1647 - accuracy: 0.9396 - val_loss: 0.2537 - val_accuracy: 0.9143
# Epoch 95/150
# 891/891 [==============================] - 28s 31ms/step - loss: 0.1636 - accuracy: 0.9394 - val_loss: 0.2532 - val_accuracy: 0.9177
# Epoch 96/150
# 891/891 [==============================] - 28s 31ms/step - loss: 0.1624 - accuracy: 0.9399 - val_loss: 0.2531 - val_accuracy: 0.9127
# Epoch 97/150
# 891/891 [==============================] - 28s 31ms/step - loss: 0.1649 - accuracy: 0.9374 - val_loss: 0.2520 - val_accuracy: 0.9153
# Epoch 98/150
# 891/891 [==============================] - 28s 31ms/step - loss: 0.1596 - accuracy: 0.9404 - val_loss: 0.2575 - val_accuracy: 0.9147
# Epoch 99/150
# 891/891 [==============================] - 28s 31ms/step - loss: 0.1624 - accuracy: 0.9391 - val_loss: 0.2485 - val_accuracy: 0.9160
# Epoch 100/150
# 891/891 [==============================] - 29s 33ms/step - loss: 0.1651 - accuracy: 0.9385 - val_loss: 0.2481 - val_accuracy: 0.9170
# Epoch 101/150
# 891/891 [==============================] - 28s 31ms/step - loss: 0.1642 - accuracy: 0.9376 - val_loss: 0.2562 - val_accuracy: 0.9160
# Epoch 102/150
# 891/891 [==============================] - 28s 31ms/step - loss: 0.1589 - accuracy: 0.9403 - val_loss: 0.2530 - val_accuracy: 0.9140
# Epoch 103/150
# 891/891 [==============================] - 28s 32ms/step - loss: 0.1639 - accuracy: 0.9383 - val_loss: 0.2522 - val_accuracy: 0.9103
# Epoch 104/150
# 891/891 [==============================] - 28s 32ms/step - loss: 0.1609 - accuracy: 0.9402 - val_loss: 0.2511 - val_accuracy: 0.9167
# Epoch 105/150
# 891/891 [==============================] - 28s 32ms/step - loss: 0.1591 - accuracy: 0.9408 - val_loss: 0.2662 - val_accuracy: 0.9170
# Epoch 106/150
# 891/891 [==============================] - 30s 34ms/step - loss: 0.1595 - accuracy: 0.9405 - val_loss: 0.2558 - val_accuracy: 0.9167
# Epoch 107/150
# 891/891 [==============================] - 36s 40ms/step - loss: 0.1577 - accuracy: 0.9407 - val_loss: 0.2574 - val_accuracy: 0.9187
# Epoch 108/150
# 891/891 [==============================] - 39s 44ms/step - loss: 0.1593 - accuracy: 0.9413 - val_loss: 0.2466 - val_accuracy: 0.9150
# Epoch 109/150
# 891/891 [==============================] - 34s 38ms/step - loss: 0.1601 - accuracy: 0.9390 - val_loss: 0.2446 - val_accuracy: 0.9153
# Epoch 110/150
# 891/891 [==============================] - 34s 38ms/step - loss: 0.1582 - accuracy: 0.9402 - val_loss: 0.2552 - val_accuracy: 0.9190
# Epoch 111/150
# 891/891 [==============================] - 34s 38ms/step - loss: 0.1577 - accuracy: 0.9410 - val_loss: 0.2620 - val_accuracy: 0.9140
# Epoch 112/150
# 891/891 [==============================] - 33s 37ms/step - loss: 0.1609 - accuracy: 0.9401 - val_loss: 0.2496 - val_accuracy: 0.9170
# Epoch 113/150
# 891/891 [==============================] - 34s 38ms/step - loss: 0.1572 - accuracy: 0.9406 - val_loss: 0.2500 - val_accuracy: 0.9160
# Epoch 114/150
# 891/891 [==============================] - 38s 43ms/step - loss: 0.1550 - accuracy: 0.9416 - val_loss: 0.2590 - val_accuracy: 0.9147
# Epoch 115/150
# 891/891 [==============================] - 34s 38ms/step - loss: 0.1596 - accuracy: 0.9403 - val_loss: 0.2473 - val_accuracy: 0.9160
# Epoch 116/150
# 891/891 [==============================] - 34s 39ms/step - loss: 0.1574 - accuracy: 0.9417 - val_loss: 0.2563 - val_accuracy: 0.9167
# Epoch 117/150
# 891/891 [==============================] - 31s 35ms/step - loss: 0.1538 - accuracy: 0.9416 - val_loss: 0.2584 - val_accuracy: 0.9127
# Epoch 118/150
# 891/891 [==============================] - 33s 37ms/step - loss: 0.1552 - accuracy: 0.9419 - val_loss: 0.2581 - val_accuracy: 0.9173
# Epoch 119/150
# 891/891 [==============================] - 37s 42ms/step - loss: 0.1566 - accuracy: 0.9404 - val_loss: 0.2550 - val_accuracy: 0.9150
# Epoch 120/150
# 891/891 [==============================] - 38s 43ms/step - loss: 0.1571 - accuracy: 0.9412 - val_loss: 0.2529 - val_accuracy: 0.9160
# Epoch 121/150
# 891/891 [==============================] - 39s 43ms/step - loss: 0.1538 - accuracy: 0.9418 - val_loss: 0.2618 - val_accuracy: 0.9160
# Epoch 122/150
# 891/891 [==============================] - 39s 43ms/step - loss: 0.1543 - accuracy: 0.9421 - val_loss: 0.2696 - val_accuracy: 0.9137
# Epoch 123/150
# 891/891 [==============================] - 40s 45ms/step - loss: 0.1537 - accuracy: 0.9422 - val_loss: 0.2570 - val_accuracy: 0.9170
# Epoch 124/150
# 891/891 [==============================] - 39s 43ms/step - loss: 0.1564 - accuracy: 0.9416 - val_loss: 0.2612 - val_accuracy: 0.9183
# Epoch 125/150
# 891/891 [==============================] - 37s 42ms/step - loss: 0.1530 - accuracy: 0.9421 - val_loss: 0.2592 - val_accuracy: 0.9183
# Epoch 126/150
# 891/891 [==============================] - 43s 49ms/step - loss: 0.1540 - accuracy: 0.9421 - val_loss: 0.2635 - val_accuracy: 0.9177
# Epoch 127/150
# 891/891 [==============================] - 45s 50ms/step - loss: 0.1539 - accuracy: 0.9414 - val_loss: 0.2597 - val_accuracy: 0.9073
# Epoch 128/150
# 891/891 [==============================] - 46s 51ms/step - loss: 0.1518 - accuracy: 0.9424 - val_loss: 0.2604 - val_accuracy: 0.9093
# Epoch 129/150
# 891/891 [==============================] - 36s 41ms/step - loss: 0.1507 - accuracy: 0.9437 - val_loss: 0.2607 - val_accuracy: 0.9123
# Epoch 130/150
# 891/891 [==============================] - 34s 38ms/step - loss: 0.1554 - accuracy: 0.9417 - val_loss: 0.2653 - val_accuracy: 0.9120
# Epoch 131/150
# 891/891 [==============================] - 43s 49ms/step - loss: 0.1548 - accuracy: 0.9432 - val_loss: 0.2580 - val_accuracy: 0.9190
# Epoch 132/150
# 891/891 [==============================] - 38s 43ms/step - loss: 0.1507 - accuracy: 0.9436 - val_loss: 0.2632 - val_accuracy: 0.9123
# Epoch 133/150
# 891/891 [==============================] - 36s 41ms/step - loss: 0.1508 - accuracy: 0.9431 - val_loss: 0.2665 - val_accuracy: 0.9173
# Epoch 134/150
# 891/891 [==============================] - 40s 45ms/step - loss: 0.1554 - accuracy: 0.9421 - val_loss: 0.2644 - val_accuracy: 0.9160
# Epoch 135/150
# 891/891 [==============================] - 39s 44ms/step - loss: 0.1485 - accuracy: 0.9445 - val_loss: 0.2651 - val_accuracy: 0.9150
# Epoch 136/150
# 891/891 [==============================] - 39s 43ms/step - loss: 0.1515 - accuracy: 0.9439 - val_loss: 0.2576 - val_accuracy: 0.9177
# Epoch 137/150
# 891/891 [==============================] - 39s 43ms/step - loss: 0.1524 - accuracy: 0.9429 - val_loss: 0.2723 - val_accuracy: 0.9160
# Epoch 138/150
# 891/891 [==============================] - 38s 43ms/step - loss: 0.1498 - accuracy: 0.9437 - val_loss: 0.2578 - val_accuracy: 0.9170
# Epoch 139/150
# 891/891 [==============================] - 37s 41ms/step - loss: 0.1513 - accuracy: 0.9426 - val_loss: 0.2633 - val_accuracy: 0.9117
# Epoch 140/150
# 891/891 [==============================] - 35s 40ms/step - loss: 0.1531 - accuracy: 0.9430 - val_loss: 0.2638 - val_accuracy: 0.9180
# Epoch 141/150
# 891/891 [==============================] - 35s 40ms/step - loss: 0.1500 - accuracy: 0.9437 - val_loss: 0.2560 - val_accuracy: 0.9147
# Epoch 142/150
# 891/891 [==============================] - 38s 42ms/step - loss: 0.1491 - accuracy: 0.9435 - val_loss: 0.2590 - val_accuracy: 0.9093
# Epoch 143/150
# 891/891 [==============================] - 41s 46ms/step - loss: 0.1518 - accuracy: 0.9424 - val_loss: 0.2665 - val_accuracy: 0.9150
# Epoch 144/150
# 891/891 [==============================] - 29s 32ms/step - loss: 0.1516 - accuracy: 0.9429 - val_loss: 0.2558 - val_accuracy: 0.9193
# Epoch 145/150
# 891/891 [==============================] - 29s 33ms/step - loss: 0.1492 - accuracy: 0.9445 - val_loss: 0.2616 - val_accuracy: 0.9147
# Epoch 146/150
# 891/891 [==============================] - 29s 33ms/step - loss: 0.1452 - accuracy: 0.9445 - val_loss: 0.2595 - val_accuracy: 0.9133
# Epoch 147/150
# 891/891 [==============================] - 28s 32ms/step - loss: 0.1507 - accuracy: 0.9431 - val_loss: 0.2663 - val_accuracy: 0.9200
# Epoch 148/150
# 891/891 [==============================] - 28s 32ms/step - loss: 0.1474 - accuracy: 0.9446 - val_loss: 0.2748 - val_accuracy: 0.9180
# Epoch 149/150
# 891/891 [==============================] - 28s 32ms/step - loss: 0.1526 - accuracy: 0.9441 - val_loss: 0.2618 - val_accuracy: 0.9097
# Epoch 150/150
# 891/891 [==============================] - 28s 32ms/step - loss: 0.1471 - accuracy: 0.9446 - val_loss: 0.2640 - val_accuracy: 0.9180

# %%
plt.style.use('ggplot')
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1) 
plt.plot(np.arange(0, len(hist.history['loss'])), hist.history['loss'], label='train_loss')
plt.plot(np.arange(0, len(hist.history['val_loss'])), hist.history['val_loss'], label='val_loss')
plt.title('Loss Learning Curve')
plt.xlabel('Epoch #')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2) 
plt.plot(np.arange(0, len(hist.history['accuracy'])), hist.history['accuracy'], label='train_accuracy')
plt.plot(np.arange(0, len(hist.history['val_accuracy'])), hist.history['val_accuracy'], label='val_accuracy')
plt.title('Accuracy Learning Curve')
plt.xlabel('Epoch #')
plt.ylabel('Accuracy')  
plt.legend()

plt.show()

# %%
print('Networking!')
logits = model.predict(X_test, batch_size=50)
print(logits)
# Out:
# Networking!
# 200/200 [==============================] - 1s 7ms/step
# [[9.96588349e-01 1.25302642e-11 6.81317295e-04 ... 9.02138815e-20
#   9.67283320e-09 1.20363937e-21]
#  [9.02452210e-11 1.00000000e+00 2.23372279e-10 ... 2.68542015e-18
#   5.93850802e-11 4.77560598e-14]
#  [1.13953211e-04 2.92324401e-20 9.97009754e-01 ... 1.58848314e-23
#   4.26635418e-15 7.06530686e-22]
#  ...
#  [8.52996006e-16 7.18309854e-27 1.35986825e-16 ... 2.31930115e-24
#   1.00000000e+00 1.94019090e-19]
#  [6.53468451e-05 2.67339129e-13 1.57469594e-06 ... 1.79548793e-20
#   9.99894977e-01 1.32635026e-14]
#  [1.29171110e-06 9.99914050e-01 1.77254005e-05 ... 5.58360773e-15
#   2.00706927e-05 1.17427647e-11]]

# %% [markdown]
# STEP 5: Get the accuracies and F1 score.

# %%
y_predict = np.argmax(logits, axis=1)
TestingAccuracy = accuracy_score(y_test, y_predict)
f1Test = f1_score(y_test, y_predict, average='weighted')
Classfication = classification_report(y_test, y_predict)

Scores = pd.DataFrame({
    'Accuracy_Training': [0.947],
    'Accuracy_Testing': [TestingAccuracy],
    'F1_Score_Test': [f1Test],
    'Time (minutes)': [92.12]  
})
Scores
# Out:
#    Accuracy_Training  Accuracy_Testing  F1_Score_Test  Time (minutes)
# 0              0.947             0.922       0.921582           92.12

# %%
classes=['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']
print(
    classification_report(
        y_test, y_predict, target_names=classes
    )
)
# Out:
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.82      0.91      0.86      1000
#      Trouser       1.00      0.98      0.99      1000
#     Pullover       0.88      0.89      0.88      1000
#        Dress       0.93      0.94      0.93      1000
#         Coat       0.89      0.88      0.89      1000
#       Sandal       0.99      0.98      0.98      1000
#        Shirt       0.81      0.73      0.76      1000
#      Sneaker       0.94      0.97      0.96      1000
#          Bag       0.99      0.99      0.99      1000
#   Ankle boot       0.98      0.95      0.97      1000
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000

# %% [markdown]
# STEP 8: Visualizing using the Confusion Matrix.

# %%
cm = confusion_matrix(y_test, y_predict)
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Reds", cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Prediction')
plt.ylabel('Actual')
plt.show()
